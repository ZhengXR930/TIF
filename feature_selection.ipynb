# %%
import os
import pandas as pd
import numpy as np
import pickle

dataset_folder = "/Users/zhengxinran/Documents/S2LAB/dataset/tif/combine_drebin"
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

adware_push = [
    'airpush', 'revmob', 'adwo', 'domob', 'youmi', 'kuguo', 'zdtad',
    'minimob', 'gumen', 'mobwin', 'wkload', 'callflakes', 'ganlet',
    'pandaad', 'dianjin', 'mobidash', 'adflex', 'mecor', 'gexin',
    'jiead', 'odpa', 'dianle', 'mobeleader'
]

adware_silent = [
    'dowgin', 'leadbolt', 'gappusin', 'plankton', 'shixot', 'tekwon',
    'skplanet', 'gizmo', 'qumi', 'autoins'
]

riskware_priv = [
    'feiad', 'kyview', 'viser', 'admogo', 'feiwo', 'appoffer', 'skymobi',
    'joye', 'fengvi', 'appinventor', 'fobus', 'invent','cnzz'
]

sms_trojan = [
    'smsreg', 'smssend', 'hipposms', 'smsagent', 'smspay'
]

fake_installer = [
    'fakeinst', 'shedun', 'spyagent', 'fakeangry', 'fakeflash', 'torjok'
]

dropper = [
    'nandrobox', 'systemmonitor', 'toreoc', 'appsgeyser', 'commplat',
    'jiagu', 'ewind', 'leapp', 'anydown', 'ginmaster'
]


unknown = [
    'unknown', 'oveead', 'systush', 'gomunc', 'reflod', 'buzztouch',
    'umpay', 'kirko', 'bauts', 'tachi', 'dnotua', 'frupi'
]


all_types = adware_push + adware_silent + riskware_priv + sms_trojan + fake_installer + dropper  + unknown

dfs_train = []
dfs_test = []
for month in months:
    file_path = os.path.join(dataset_folder, f'2014-{month}', 'features.pkl')
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    dfs_train.append(data)

for year in years:
    for month in months:
        file_path = os.path.join(dataset_folder, f'{year}-{month}', 'features.pkl')
        with open(file_path, 'rb') as f:
            data = pickle.load(f)
        dfs_test.append(data)

df_train = pd.concat(dfs_train)
print(df_train.shape)

df_test = pd.concat(dfs_test)
print(df_test.shape)

print(df_train.columns)
print(df_test.columns)
        

train_family = df_train['family'].tolist()
diff_family = set(train_family) - set(all_types)
print(diff_family)


# allocate type to each row
# Out:
# (51953, 6)
# (292701, 6)
# Index(['sha256', 'dex_date', 'label', 'family', 'vt_detection',
#        'json_features'],
#       dtype='object')
# Index(['sha256', 'dex_date', 'label', 'family', 'vt_detection',
#        'json_features'],
#       dtype='object')
# {'benign'}

# %%
def allocate_type(x):
    if x in adware_push:
        return 'adware_push'
    elif x in adware_silent:
        return 'adware_silent'
    elif x in riskware_priv:
        return 'riskware_priv'
    elif x in sms_trojan:
        return 'sms_trojan'
    elif x in fake_installer:
        return 'fake_installer'
    elif x in dropper:
        return 'dropper'
    elif x in unknown:
        return 'unknown'
    elif x == 'benign':
        return 'benign'
    else:
        print(f"family {x} not found")

df_train['type'] = df_train['family'].apply(allocate_type)
group_type = df_train.groupby('type')
print(df_train['type'].value_counts())
# Out:
# type
# benign            46536
# adware_silent      2473
# adware_push        2030
# unknown             303
# riskware_priv       241
# sms_trojan          238
# dropper              76
# fake_installer       56
# Name: count, dtype: int64

# %%
# adware_silent
df_as = df_train[df_train['type'] == 'adware_silent']
print(df_as.shape)

# adware_push
df_ap = df_train[df_train['type'] == 'adware_push']
print(df_ap.shape)

# riskware_priv
df_rp = df_train[df_train['type'] == 'riskware_priv']
print(df_rp.shape)

# sms_trojan
df_st = df_train[df_train['type'] == 'sms_trojan']
print(df_st.shape)

# fake_installer
df_fi = df_train[df_train['type'] == 'fake_installer']
print(df_fi.shape)

# dropper
df_dp = df_train[df_train['type'] == 'dropper']
print(df_dp.shape)

# unknown
df_unk = df_train[df_train['type'] == 'unknown']
print(df_unk.shape)

# benign
df_ben = df_train[df_train['type'] == 'benign']
print(df_ben.shape)
# Out:
# (2473, 7)
# (2030, 7)
# (241, 7)
# (238, 7)
# (56, 7)
# (76, 7)
# (303, 7)
# (46536, 7)

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

def drebin_svm_train(X_train, y_train):
    print(f"train Linear SVM")
    clf = LinearSVC(C=1.0, max_iter=10000)
    clf.fit(X_train, y_train)

    return clf

def drebin_svm_pred(clf, X_test, y_test):
    print(f"eval Linear SVM on overall test data")
    pred_labels = clf.predict(X_test)

    precision = precision_score(y_test, pred_labels,average='macro')
    recall = recall_score(y_test, pred_labels,average='macro')
    f1 = f1_score(y_test, pred_labels,average='macro')

    print(f"precision: {precision}, recall: {recall}, f1: {f1}")

    return precision, recall, f1

# %%
# adware_silent feature selection
# set random seed
from sklearn.svm import LinearSVC
from scipy.sparse import csr_matrix, vstack, save_npz, load_npz, issparse
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_selection import VarianceThreshold, SelectFromModel, SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

np.random.seed(42)

def ensure_sparse(X):
    """Ensure X is a sparse matrix (CSR format)"""
    if not issparse(X):
        X = csr_matrix(X)
    elif not isinstance(X, csr_matrix):
        X = csr_matrix(X)
    return X

def select_features(data, seg = 'json_features'):
    

    X_train = data[seg].values
    y_train = data['label'].values

    # vectorize
    vec = DictVectorizer(sparse=True, sort=True)
    X_train_vectorized = vec.fit_transform(X_train)
    print(f"before feature selection: {X_train_vectorized.shape}")
    all_feature_names = vec.get_feature_names_out()

    print(f"all_feature_names: {len(all_feature_names)}, {X_train_vectorized.shape}")

    n_features = X_train_vectorized.shape[1]
    max_features = min(10000, n_features)

    # feature selection
    # selector = SelectFromModel(LinearSVC(C=0.01, penalty="l1", dual=False), max_features=max_features)
    selector = SelectFromModel(RandomForestClassifier(n_estimators=100, max_depth=None, random_state=42), max_features=max_features)
    selector.fit(X_train_vectorized, y_train)
    print(selector.get_support())

    feature_mask = selector.get_support()
    selected_feature_names = vec.get_feature_names_out()[feature_mask]
    print(selected_feature_names[:10])

    # Create a mapping from feature names to their indices
    name_to_index = {name: idx for idx, name in enumerate(all_feature_names)}

    selected_indices = [name_to_index[name] for name in selected_feature_names]
                
    # Select features from training data in the EXACT SAME ORDER
    X_train_selected = X_train_vectorized[:, selected_indices]
    X_train_selected = ensure_sparse(X_train_selected)

    print(X_train_selected.shape)
    return X_train_selected, y_train, selected_feature_names


# load process features name
path = "/Users/zhengxinran/Documents/S2LAB/dataset/tif/processed_features/selected_features_linearsvc.txt"
feature_names = []
with open(path, 'r') as f:
    for line in f:
        feature_names.append(line.strip())

def filter_features(feature_dict, feature_name_list):
    return {k: v for k, v in feature_dict.items() if k in feature_name_list}
    
# set benign_num
benign_num = df_as.shape[0] * 9
df_ben_selected = df_ben.sample(benign_num)

data = pd.concat([df_ben_selected, df_as])
#  for each row, select the features in feature_names
feature_name_set = set(feature_names)

def filter_features_fast(feature_dict):
    return {k: v for k, v in feature_dict.items() if k in feature_name_set}

data["selected_features"] = data["json_features"].apply(filter_features_fast)

# %%
X_type_selected, y_type_selected, selected_feature_names_type = select_features(data, seg = 'json_features')
X_def_selected, y_def_selected, selected_feature_names_def = select_features(data, seg = 'selected_features')

print(len(selected_feature_names_type))
print(len(selected_feature_names_def))
# Out:
# before feature selection: (24730, 7660)
# all_feature_names: 7660, (24730, 7660)
# [False False False ... False False False]
# ['activities::CreateShortcuts' 'activities::Dashboard'
#  'activities::IntroFlow' 'activities::MAME4droid Define Keys'
#  'activities::MAME4droid Help' 'activities::MAME4droid Player Keys'
#  'activities::MAME4droid Preferences' 'activities::Main'
#  'activities::NativeBrowser' 'activities::Select Key']
# (24730, 559)
# 559

# %%
diff_feature_names = set(selected_feature_names_type) - set(selected_feature_names_def)
print(len(diff_feature_names))
# print(diff_feature_names)
# Out:
# 9449

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train_selected, y_test_selected = train_test_split(X_type_selected, y_type_selected, test_size=0.2, random_state=42)

# evaluate
clf = drebin_svm_train(X_train, y_train_selected)
precision, recall, f1 = drebin_svm_pred(clf, X_test, y_test_selected)
# Out:
# train Linear SVM
# eval Linear SVM on overall test data
# precision: 0.9910877344406948, recall: 0.9839702870535665, f1: 0.987495771094882

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train_selected, y_test_selected = train_test_split(X_def_selected, y_def_selected, test_size=0.2, random_state=42)

# evaluate
clf = drebin_svm_train(X_train, y_train_selected)
precision, recall, f1 = drebin_svm_pred(clf, X_test, y_test_selected)
# Out:
# train Linear SVM
# eval Linear SVM on overall test data
# precision: 0.9900713399288681, recall: 0.983858028409651, f1: 0.9869393125452428

# %%
# selected features
feature_path = "/scratch_NOT_BACKED_UP/NOT_BACKED_UP/xinran/dataset/processed_features/selected_features_randomforest.txt"
with open(feature_path, 'r') as f:
    features = f.read().splitlines()

print(len(features))
features[:1000]
# Out:
# 5814
# ['activities:::pushservice',
#  'activities::About',
#  'activities::AboutActivity',
#  'activities::AboutScreen',
#  'activities::AboutUs',
#  'activities::Activity2',
#  'activities::ActivityPlay',
#  'activities::Ad Activity',
#  'activities::Ad Video Player',
#  'activities::Add Contact',
#  'activities::Add Your Name',
#  'activities::Android',
#  'activities::AppsgeyserApp message',
#  'activities::Bankside Village Apts',
#  'activities::CallLog',
#  'activities::ChangeAppActivity',
#  'activities::ChapterActivity',
#  'activities::Contact',
#  'activities::CreateShortcuts',
#  'activities::Dashboard',
#  'activities::DetailActivity',
#  'activities::Dreammaker',
#  'activities::ESDFL',
#  'activities::Email',
#  'activities::FamousActivity',
#  'activities::FavActivity',
#  'activities::Favourites',
#  'activities::FileChooser',
#  'activities::FireStar',
#  'activities::Floppy Pig',
#  'activities::ForceRate',
#  'activities::GameActivity',
#  'activities::GameFeat',
#  'activities::Help',
#  'activities::HelpActivity',
#  'activities::HomeActivity',
#  'activities::Ieyasu-kun Game for kids',
#  'activities::InfoActivity',
#  'activities::InputActivity',
#  'activities::IntroFlow',
#  'activities::LearnActivity',
#  'activities::LoadFeedBack',
#  'activities::Login',
#  'activities::LoginActivity',
#  'activities::MAME4droid Define Keys',
#  'activities::MAME4droid Help',
#  'activities::MAME4droid Player Keys',
#  'activities::MAME4droid Preferences',
#  'activities::Main',
#  'activities::MainActivity',
#  'activities::Mark Up Picture',
#  'activities::Match',
#  'activities::Media/MediaMetadata',
#  'activities::Media/MediaPlayer',
#  'activities::Media/VideoView',
#  'activities::MediaListActivity',
#  'activities::MediaViewActivity',
#  'activities::Menu',
#  'activities::MenuActivity',
#  'activities::Messages',
#  'activities::MonacaActivity',
#  'activities::MonacaPageActivity',
#  'activities::More DroidHen Games',
#  'activities::More Games',
#  'activities::MoreAppScreen',
#  'activities::MultiTabTest',
#  'activities::MusicActivity',
#  'activities::NativeBrowser',
#  'activities::Options',
#  'activities::Piramide',
#  'activities::Preference',
#  'activities::Preferences',
#  'activities::PreferencesActivity',
#  'activities::Prisma',
#  'activities::RUA2Activity',
#  'activities::Radiant Defense',
#  'activities::Redantic',
#  'activities::Redplaying',
#  'activities::Result',
#  'activities::ResultActivity',
#  'activities::Review',
#  'activities::Robotek',
#  'activities::Search',
#  'activities::SearchActivity',
#  'activities::Select Key',
#  'activities::Setting',
#  'activities::Settings',
#  'activities::SettingsActivity',
#  'activities::SfBeginActivity',
#  'activities::Share',
#  'activities::SkinViewActivity',
#  'activities::Smart',
#  'activities::SplashActivity',
#  'activities::SplashScreen',
#  'activities::StartActivity',
#  'activities::StateSlotsActivity',
#  'activities::TicTacToe',
#  'activities::Top Scores',
#  'activities::UMENG_APPKEY',
#  'activities::Web Authenticator',
#  'activities::WebViewActivity',
#  'activities::Zombies VS Aliens: RTS',
#  'activities::_About',
#  'activities::_AboutActivity',
#  'activities::_AboutPage',
#  'activities::_AboutUs',
#  'activities::_AboutUsActivity',
#  'activities::_ActSetting',
#  'activities::_ActWelcome',
#  'activities::_Activity',
#  'activities::_ActivityAbout',
#  'activities::_ActivityMain',
#  'activities::_ActivityMap',
#  'activities::_Activity_MyPhoto',
#  'activities::_AdMobUnityActivity',
#  'activities::_AeonRacer',
#  'activities::_AlarmAlert',
#  'activities::_AlbumActivity',
#  'activities::_AlbumScreen',
#  'activities::_AndroidActivity',
#  'activities::_AndroidNativeBridge',
#  'activities::_AndroidQuranActivity',
#  'activities::_AndromoDashboardActivity',
#  'activities::_AppActivity',
#  'activities::_AppEntry',
#  'activities::_AppLauncher',
#  'activities::_AppStart',
#  'activities::_AppStarterActivity',
#  'activities::_Application',
#  'activities::_ApplicationDemo',
#  'activities::_AppsActivity',
#  'activities::_AppsBuilderFragmentActivityFixed',
#  'activities::_AppsBuilderMain',
#  'activities::_ArtistActivity',
#  'activities::_BackScreen',
#  'activities::_BackgroundSelectActivity',
#  'activities::_BaseActivity',
#  'activities::_BaseUIActivity',
#  'activities::_BasketBallActivity',
#  'activities::_BasketBall_Shot_Activity',
#  'activities::_Beretta',
#  'activities::_BillingActivity',
#  'activities::_BookActivity',
#  'activities::_BookRegisterTopActivity',
#  'activities::_Browser',
#  'activities::_BrowserActivity',
#  'activities::_BuyActivity',
#  'activities::_CBUnityPlayerProxyActivity',
#  'activities::_CacheCleaner',
#  'activities::_Calculator',
#  'activities::_CallActivity',
#  'activities::_Camera',
#  'activities::_Carrom3DActivity',
#  'activities::_CatalogActivity',
#  'activities::_CategoriesActivity',
#  'activities::_ChatActivity',
#  'activities::_ChooseCampusActivity',
#  'activities::_ChooseContactActivity',
#  'activities::_Coco',
#  'activities::_Compass',
#  'activities::_CompassActivity',
#  'activities::_ContactUs',
#  'activities::_ContentActivity',
#  'activities::_CoronaActivity',
#  'activities::_DGunsSP',
#  'activities::_DesktopActivity',
#  'activities::_DetailActivity',
#  'activities::_DetailsActivity',
#  'activities::_DeveloperActivity',
#  'activities::_Dictionary',
#  'activities::_Digee',
#  'activities::_DolphinActivity',
#  'activities::_DummyActivity',
#  'activities::_EBrowserActivity',
#  'activities::_ElektronikaActivity',
#  'activities::_EnterHiscore',
#  'activities::_EntryActivity',
#  'activities::_EventosActivity',
#  'activities::_ExHallInfoActivity',
#  'activities::_FavoritesActivity',
#  'activities::_Favourites',
#  'activities::_FinalPlaneActivity',
#  'activities::_FirstPage',
#  'activities::_Flash',
#  'activities::_FlashActivity',
#  'activities::_FlashLight',
#  'activities::_FlashScreen',
#  'activities::_FlipBookActivity',
#  'activities::_ForSearch',
#  'activities::_FractivUnityActivity',
#  'activities::_FullImageActivity',
#  'activities::_GMIDlet',
#  'activities::_GOScreenLockInstallDialog',
#  'activities::_GSGameWrapperActivity',
#  'activities::_GTA3',
#  'activities::_GTAVC',
#  'activities::_Game',
#  'activities::_GameActivity',
#  'activities::_GameApp',
#  'activities::_GameMain',
#  'activities::_GameOpenActivity',
#  'activities::_GameOver',
#  'activities::_GamePlayActivity',
#  'activities::_GameView',
#  'activities::_GeneralWebview',
#  'activities::_GeneticsActivity',
#  'activities::_GoAct',
#  'activities::_GoodsListActivity',
#  'activities::_GoogleHome',
#  'activities::_GridActivity',
#  'activities::_GuideActivity',
#  'activities::_HelloCpp',
#  'activities::_HelloFacebookSampleActivity',
#  'activities::_HelloLua',
#  'activities::_Help',
#  'activities::_HelpAct',
#  'activities::_HelpActivity',
#  'activities::_HelpPage',
#  'activities::_Help_ChatTerms',
#  'activities::_HighScoresAct',
#  'activities::_Highscore',
#  'activities::_HighwaySpeed',
#  'activities::_Hindi',
#  'activities::_HistoryUrlScreen',
#  'activities::_Home',
#  'activities::_HomeActivity',
#  'activities::_ImageGalleryActivity',
#  'activities::_ImageGridActivity',
#  'activities::_ImageListActivity',
#  'activities::_ImagePagerActivity',
#  'activities::_ImageViewDialogActivity',
#  'activities::_IndexActivity',
#  'activities::_IndexScreen',
#  'activities::_Info',
#  'activities::_InfoActivity',
#  'activities::_Inicio',
#  'activities::_Init',
#  'activities::_InitActivity',
#  'activities::_InstaCollage',
#  'activities::_Interface',
#  'activities::_Intro',
#  'activities::_IntroActivity',
#  'activities::_ItemListActivity',
#  'activities::_JNIActivity',
#  'activities::_JNexusInterface',
#  'activities::_JumpingPanda',
#  'activities::_JumpyBall',
#  'activities::_JungleDash',
#  'activities::_KartFighter',
#  'activities::_KumoAppActivity',
#  'activities::_LaunchActivity',
#  'activities::_Launcher',
#  'activities::_LauncherActivity',
#  'activities::_LevelSelectorActivity',
#  'activities::_LinkList',
#  'activities::_ListActivity',
#  'activities::_ListNewsInfoActivity',
#  'activities::_ListsActivity',
#  'activities::_LiveWallpaperSettings',
#  'activities::_LoadAct',
#  'activities::_LoadActivity',
#  'activities::_Loading',
#  'activities::_LoadingActivity',
#  'activities::_LoadingScreen',
#  'activities::_Loading_splashActivity',
#  'activities::_LogActivity',
#  'activities::_Login',
#  'activities::_LoginActivity',
#  'activities::_Logo',
#  'activities::_LogoActivity',
#  'activities::_MAME4all',
#  'activities::_MAboutActivity',
#  'activities::_MSAboutUs',
#  'activities::_MSAccountSummary',
#  'activities::_MSAccountSummaryDetail',
#  'activities::_MSFavDelete',
#  'activities::_MSIndices',
#  'activities::_MSIndicesCategoryMenu',
#  'activities::_MSLogin2',
#  'activities::_MSMarket',
#  'activities::_MSOrderProperties',
#  'activities::_MSProfile',
#  'activities::_MSReduceOrCancelOrder',
#  'activities::_MSSettings',
#  'activities::_MSTop10',
#  'activities::_MagazineActivity',
#  'activities::_Main',
#  'activities::_MainAct',
#  'activities::_MainActivity',
#  'activities::_MainActivity1',
#  'activities::_MainApp',
#  'activities::_MainController',
#  'activities::_MainList',
#  'activities::_MainMIDlet',
#  'activities::_MainMenu',
#  'activities::_MainMenuActivity',
#  'activities::_MainNavigationActivity',
#  'activities::_MainScreen',
#  'activities::_MainShiekh',
#  'activities::_MainTabActivity',
#  'activities::_MainView',
#  'activities::_Mainmenu',
#  'activities::_ManCaveGamesActivity',
#  'activities::_MapCardActivity',
#  'activities::_MapDepotImageActivity',
#  'activities::_MapOp',
#  'activities::_MediaPlayerActivity',
#  'activities::_Menu',
#  'activities::_MenuActivity',
#  'activities::_MenuGame',
#  'activities::_MenuHelp',
#  'activities::_MenuPage',
#  'activities::_MenuScreen',
#  'activities::_MiniDashActivity',
#  'activities::_MixedColorMenuActivity',
#  'activities::_ModifyPasswordActivity',
#  'activities::_MonacaSplashActivity',
#  'activities::_MonkeyGame',
#  'activities::_MoreActivity',
#  'activities::_Moto3DTeachActivity',
#  'activities::_MyAccountActivity',
#  'activities::_MyActivity',
#  'activities::_MyAppActivity',
#  'activities::_MyCoronaActivity',
#  'activities::_MyListActivity',
#  'activities::_MyOrderActivity',
#  'activities::_MyPushAppDialog',
#  'activities::_MyVideoView',
#  'activities::_MybabybubblesgameActivity',
#  'activities::_MyninjarushActivity',
#  'activities::_NetworkActivity',
#  'activities::_NinjaChopDemons',
#  'activities::_NotificationActivity',
#  'activities::_OpeningActivity',
#  'activities::_OptionActivity',
#  'activities::_OptionListActivity',
#  'activities::_Options',
#  'activities::_OrderActivity',
#  'activities::_Other_AudioRecorder',
#  'activities::_OverActivity',
#  'activities::_PZPlayer',
#  'activities::_Paladog',
#  'activities::_PasswordActivity',
#  'activities::_PaylistActivity',
#  'activities::_PaymentScreen',
#  'activities::_PequenosVelozes',
#  'activities::_PerfectTea',
#  'activities::_PhotoActivity',
#  'activities::_Player',
#  'activities::_PlayerActivity',
#  'activities::_Preferences',
#  'activities::_PreferencesActivity',
#  'activities::_Prefs',
#  'activities::_PreviewActivity',
#  'activities::_PrismActivity',
#  'activities::_ProductDetailsActivity',
#  'activities::_ProfileActivity',
#  'activities::_PromoActivity',
#  'activities::_QuestionActivity',
#  'activities::_RecruitManagementActivity',
#  'activities::_Register',
#  'activities::_RegisterActivity',
#  'activities::_Result',
#  'activities::_RouteDemoActivity',
#  'activities::_RunnerActivity',
#  'activities::_SampleDownloaderActivity',
#  'activities::_ScoreActivity',
#  'activities::_Screen1',
#  'activities::_SearchActivity',
#  'activities::_SearchResultActivity',
#  'activities::_Select',
#  'activities::_Selector',
#  'activities::_SetUp',
#  'activities::_SetWallpaperActivity',
#  'activities::_SettingAct',
#  'activities::_SettingActivity',
#  'activities::_Settings',
#  'activities::_SettingsActivity',
#  'activities::_SettingsScreen',
#  'activities::_Settings_GeneralSettings',
#  'activities::_Setup_manual',
#  'activities::_ShareActivity',
#  'activities::_ShopappPoint',
#  'activities::_ShopappSplash',
#  'activities::_ShortCutActivity',
#  'activities::_ShowActivity',
#  'activities::_SingleActivity',
#  'activities::_SingleListItem',
#  'activities::_SkynetSplashActivity',
#  'activities::_SoftMainActivity',
#  'activities::_SongsActivity',
#  'activities::_SongsOptionsActivity',
#  'activities::_Splash',
#  'activities::_SplashActivity',
#  'activities::_SplashScreen',
#  'activities::_SplashScreenActivity',
#  'activities::_Splash_Screen',
#  'activities::_Splashinfo',
#  'activities::_Splashscreen',
#  'activities::_StarFighter3001Free',
#  'activities::_Start',
#  'activities::_StartActcity',
#  'activities::_StartActivity',
#  'activities::_StartGameActivity',
#  'activities::_StartUpActivity',
#  'activities::_StarterActivity',
#  'activities::_Startup',
#  'activities::_StartupActivity',
#  'activities::_StatMe',
#  'activities::_StationList',
#  'activities::_StoneAttack',
#  'activities::_TableList',
#  'activities::_Tactics',
#  'activities::_Tank',
#  'activities::_TapjoyFeaturedAppWebView',
#  'activities::_TeaCollection',
#  'activities::_TeaItem',
#  'activities::_TestActivity',
#  'activities::_TextShiyongActivity',
#  'activities::_TheLastDefenderHDApp',
#  'activities::_ThemePreviewActivity',
#  'activities::_TicTacToe',
#  'activities::_TopicActivity',
#  'activities::_TorusAct',
#  'activities::_TreasureHuntGameActivity',
#  'activities::_UnityPlayerActivity',
#  'activities::_UnityPlayerNativeActivity',
#  'activities::_UnityPlayerProxyActivity',
#  'activities::_UserInfoActivity',
#  'activities::_User_info',
#  'activities::_VerdeActivity',
#  'activities::_VersionInfo',
#  'activities::_VeryAngryRobotsActivity',
#  'activities::_VideoPlayer',
#  'activities::_ViewActivity',
#  'activities::_ViewController',
#  'activities::_ViewGuide',
#  'activities::_ViewPage',
#  'activities::_VservAdManager',
#  'activities::_WallpaperSettings',
#  'activities::_Weapons',
#  'activities::_WebActivity',
#  'activities::_WebPage',
#  'activities::_WebViewActivity',
#  'activities::_WelActivity',
#  'activities::_WelComeActivity',
#  'activities::_Welcome',
#  'activities::_WelcomeA',
#  'activities::_WelcomeActivity',
#  'activities::_WelcomeUI',
#  'activities::_WoodBridgesFreeActivity',
#  'activities::_WordActivity',
#  'activities::_WpHm',
#  'activities::_Write_recompose',
#  'activities::__Project',
#  'activities::_a',
#  'activities::_about_me',
#  'activities::_activities_MainActivity',
#  'activities::_activity',
#  'activities::_activity_AboutActivity',
#  'activities::_activity_AboutUsActivity',
#  'activities::_activity_ArticleNormalListActivity',
#  'activities::_activity_CollectActivity',
#  'activities::_activity_CommentActivity',
#  'activities::_activity_CreditsActivity',
#  'activities::_activity_DetailActivity',
#  'activities::_activity_DetailArticleSubActivity',
#  'activities::_activity_EmbedBrowserActivity',
#  'activities::_activity_EnterMapActivity',
#  'activities::_activity_FeedbackActivity',
#  'activities::_activity_GPSStatusActivity',
#  'activities::_activity_GuideActivity',
#  'activities::_activity_Help',
#  'activities::_activity_HelpActivity',
#  'activities::_activity_HomeActivity',
#  'activities::_activity_IndustryInforActivity',
#  'activities::_activity_LoginActivity',
#  'activities::_activity_Main',
#  'activities::_activity_MainActivity',
#  'activities::_activity_MainFragmentActivity',
#  'activities::_activity_MainTabActivity',
#  'activities::_activity_MapViewActivity',
#  'activities::_activity_MessageActivity',
#  'activities::_activity_MoreActivity',
#  'activities::_activity_Preferences',
#  'activities::_activity_ProductActivity',
#  'activities::_activity_ProductSubHeadListActivity',
#  'activities::_activity_ProductTwoActivity',
#  'activities::_activity_RecordActivity',
#  'activities::_activity_RegisterActivity',
#  'activities::_activity_ScanResultActivity',
#  'activities::_activity_SearchActivity',
#  'activities::_activity_ServiceCenterActivity',
#  'activities::_activity_SettingActivity',
#  'activities::_activity_ShareActivity',
#  'activities::_activity_SplashActivity',
#  'activities::_activity_UserEditActivity',
#  'activities::_activity_UsersMenuActivity',
#  'activities::_activity_WaveDetailActivity',
#  'activities::_activity_WebActivity',
#  'activities::_activity_WebViewActivity',
#  'activities::_activity_WelcomeActivity',
#  'activities::_activity_coin_CoinPurchaseActivity',
#  'activities::_app',
#  'activities::_app_more_activity_CodeAppActivity',
#  'activities::_app_more_activity_RegisterActivity',
#  'activities::_app_product_activity_ProductDetailsActivity',
#  'activities::_base_model_guide_GuideActivity',
#  'activities::_c',
#  'activities::_classes_activity_CopyClassesActivity',
#  'activities::_company_AccountTypeListMessageActivity',
#  'activities::_company_CompanyAllListActivity',
#  'activities::_company_IndustryEnterprisesActivity',
#  'activities::_crop_CropImageActivity',
#  'activities::_cu_IRSA',
#  'activities::_cycc_android',
#  'activities::_d',
#  'activities::_detail_InfoDetailsActivity',
#  'activities::_f',
#  'activities::_first',
#  'activities::_frontpage',
#  'activities::_gui_SudokuEditActivity',
#  'activities::_info_InfoCommentActivity',
#  'activities::_info_InformationDetailsActivity',
#  'activities::_krazyracers',
#  'activities::_library_user_MyWantEditActivity',
#  'activities::_main',
#  'activities::_mainActivity',
#  'activities::_main_BusinessActivity',
#  'activities::_main_Theme4Activity',
#  'activities::_more_AppLoginActivity',
#  'activities::_more_MoreActivity',
#  'activities::_more_UpdateCompanySortActivity',
#  'activities::_more_UpdateEmailActivity',
#  'activities::_more_UpdatePwdActivity',
#  'activities::_player_name_list',
#  'activities::_ppom_PpomPpompyDetail',
#  'activities::_product_AccountProductListActivity',
#  'activities::_product_ProductNewActivity',
#  'activities::_readmode_ReadModeActivity',
#  'activities::_register_UtoooRegisterUI',
#  'activities::_revmobTemplate',
#  'activities::_sdsaicheActivity',
#  'activities::_sell_SellCommentActivity',
#  'activities::_setting_PrivacyActivity',
#  'activities::_share_ShareActivity',
#  'activities::_splash',
#  'activities::_team_name_player',
#  'activities::_team_name_rank',
#  'activities::_twxes10',
#  'activities::_ui_FoursquareVenueListActivity',
#  'activities::_ui_FullScreenImage',
#  'activities::_ui_LoginActivity',
#  'activities::_ui_MainActivity',
#  'activities::_ui_MoreActivity',
#  'activities::_ui_NewsDetailActivity',
#  'activities::_ui_PreferencesActivity',
#  'activities::_ui_SearchActivity',
#  'activities::_ui_SettingActivity',
#  'activities::_ui_SplashActivity',
#  'activities::_ui_activities_ChannelResultActivity',
#  'activities::_ui_activity_AboutActivity',
#  'activities::_ui_activity_SettingActivity',
#  'activities::_view_ecommerce_InfoActivity',
#  'activities::_views_sonviews_AroundMapActivity',
#  'activities::_views_sonviews_BlogSetActivity',
#  'activities::_views_sonviews_BlogWriteActivity',
#  'activities::_views_sonviews_BookActivity',
#  'activities::_views_sonviews_LoginActivity',
#  'activities::_views_sonviews_MySupplyPublishActivity',
#  'activities::_views_sonviews_ProductListActivity',
#  'activities::_views_sonviews_YelloPageActivity',
#  'activities::_views_sonviews_showBigImgAct',
#  'activities::_wxapi_WXEntryActivity',
#  'activities::_yxapi_YXEntryActivity',
#  'activities::albaraka tourism',
#  'activities::all_parttimeguidesystem_ui_AdContentUI',
#  'activities::android_intent_category_DEFAULT',
#  'activities::android_os_framework_BaseUIActivity',
#  'activities::android_permission_INTERNET',
#  'activities::android_support_PARENT_ACTIVITY',
#  'activities::anniezc_Ni',
#  'activities::anywheresoftware_b4a_objects_preferenceactivity',
#  'activities::arabesque_android_tpl_webbase_ScreenshotsActivity',
#  'activities::baseui_VideoPlayer',
#  'activities::cn_Oleaster_util_GameApp',
#  'activities::cn_Oleaster_util_ProgressAppDown',
#  'activities::cn_apps123_shell_home_page_layout12_Home_PageLayout12FragmentActivity',
#  'activities::cn_apps123_shell_home_page_layout17_Home_PageLayout17FragmentActivity',
#  'activities::cn_apps123_shell_home_page_layout18_Home_PageLayout18FragmentActivity',
#  'activities::cn_apps123_shell_home_page_layout21_Home_PageLayout21FragmentActivity',
#  'activities::cn_apps123_shell_home_page_layout22_Home_PageLayout22FragmentActivity',
#  'activities::cn_apps123_shell_home_page_layout8_Home_PageLayout8FragmentActivity',
#  'activities::cn_apps123_shell_home_page_layout9_Home_PageLayout9FragmentActivity',
#  'activities::cn_apps123_shell_tabs_about_merchant_layout3_About_MerchantLayout3Activity',
#  'activities::cn_apps123_shell_tabs_branches_enquiry_layout3_SearchInsetMapActivity',
#  'activities::cn_apps123_shell_tabs_sqcircle_layout1_SQCircleLayout1LoginActivity',
#  'activities::cn_apptrade_ui_more_ForusActivity',
#  'activities::cn_apptrade_ui_wanted_NewestWantedActivity',
#  'activities::cn_apptrade_ui_wanted_WantedListActivity',
#  'activities::cn_bighead_activities_AboutActivity',
#  'activities::cn_cmgame_billing_ui_GameOpenActivity',
#  'activities::cn_com_lw_BitmapActivity',
#  'activities::cn_com_lw_LockScreenPreferenceActivity',
#  'activities::cn_com_lw_MazeActivity',
#  'activities::cn_com_lw_ShortcutListActivity',
#  'activities::cn_com_wiisoft_pingping_gamelevel_Level13',
#  'activities::cn_com_wiisoft_pingping_gamelevel_Level20',
#  'activities::cn_com_wiisoft_pingping_gamelevel_Level31',
#  'activities::cn_domob_android_ads_DomobActivity',
#  'activities::cn_douwan_sdk_LoginActivity',
#  'activities::cn_douwan_sdk_ServiceSystemActivity',
#  'activities::cn_emagsoftware_gamebilling_activity_BillingActivity',
#  'activities::cn_emagsoftware_gamebilling_activity_GameDialogActivity',
#  'activities::cn_emagsoftware_gamebilling_activity_GameOpenActivity',
#  'activities::cn_game189_sms_SMS',
#  'activities::cn_jpush_android_ui_PushActivity',
#  'activities::cn_mchina_client3_ui_CaptureResultActivity',
#  'activities::cn_mchina_client3_ui_HomeFragmentActivity',
#  'activities::cn_mchina_client3_ui_MainTabActivity',
#  'activities::cn_mchina_client3_ui_NoticeDetialActivity',
#  'activities::cn_mchina_client3_ui_SupplybuyLstActivity',
#  'activities::cn_mchina_client7_ui_JpushNotificationDetailActivity',
#  'activities::cn_mchina_mbrowser_zing_camera_CaptureActivity',
#  'activities::cn_sharesdk_framework_ShareSDKUIShell',
#  'activities::cn_waps_OffersWebView',
#  'activities::com_GpsWidget0101_1_DevEngine_handler_HandlerActivity',
#  'activities::com_GpsWidget0101_1_DevEngine_resource_ResourceActivity',
#  'activities::com_IQzone_postitial_activity_backing_OverlayClosingActivityImpl',
#  'activities::com_PasswordChecker8849_DevEngine_audio_AudioActivity',
#  'activities::com_PasswordChecker8849_DevEngine_base_BaseActivity',
#  'activities::com_PasswordChecker8849_DevEngine_handler_HandlerActivity',
#  'activities::com_PasswordChecker8849_DevEngine_opengl_OpenGLActivity',
#  'activities::com_a182456929452afa63557eac3a_a34796181a_cordovaExample',
#  'activities::com_abarakat_webview_WebViewActivity',
#  'activities::com_abc_de_ui_DSWV',
#  'activities::com_adcocoa_sdk_AdcocoaPopupActivity',
#  'activities::com_adfeiwo_ad_appwall_WA',
#  'activities::com_adfeiwo_banner_WebViewActivity',
#  'activities::com_adfonic_android_AdfonicActivity',
#  'activities::com_admarvel_android_ads_AdMarvelActivity',
#  'activities::com_admob_android_ads_AdMobActivity',
#  'activities::com_adsdk_sdk_banner_InAppWebView',
#  'activities::com_adsdk_sdk_mraid_MraidActivity',
#  'activities::com_adsdk_sdk_mraid_MraidBrowser',
#  'activities::com_adsdk_sdk_video_RichMediaActivity',
#  'activities::com_adsmogo_adview_AdsMogoInterstitialActivity',
#  'activities::com_adsmogo_adview_AdsMogoWebView',
#  'activities::com_adsmogo_splash_AdsMogoSplashWebView',
#  'activities::com_airkast_tunekast3_activities_AlarmActivity',
#  'activities::com_airkast_tunekast3_activities_WebContentActivity',
#  'activities::com_airpush_android_BrowserActivity',
#  'activities::com_airpush_android_PushAds',
#  'activities::com_aiya_woqu_app_MainActivity',
#  'activities::com_alawar_moregames_activities_information_FreeGameInfoActivity',
#  'activities::com_alipay_android_app_sdk_WapPayActivity',
#  'activities::com_alipay_android_mini_window_sdk_MiniWebActivity',
#  'activities::com_amazon_ags_html5_overlay_GameCircleAlertUserInterface',
#  'activities::com_amazon_ags_html5_overlay_GameCircleUserInterface',
#  'activities::com_amazon_device_ads_AdActivity',
#  'activities::com_amazon_identity_auth_device_authorization_AuthorizationActivity',
#  'activities::com_amoad_amoadsdk_AMoAdSdkWallActivity',
#  'activities::com_android_camera_CropImage',
#  'activities::com_android_guc_duduniao_MenuCredits',
#  'activities::com_android_guc_duduniao_MenuHelp',
#  'activities::com_android_vegs_gaochu_QA',
#  'activities::com_android_vending_InAppActivity',
#  'activities::com_androidemu_dragonball_CheatsActivity',
#  'activities::com_androidemu_dragonball_EmulatorActivity',
#  'activities::com_androidemu_dragonball_MainActivity',
#  'activities::com_androidemu_dragonball_StateSlotsActivity',
#  'activities::com_androidemu_gba_FileChooser',
#  'activities::com_androidemu_gba_KeyProfilesActivity',
#  'activities::com_androidemu_nes_CheatsActivity',
#  'activities::com_androidemu_nes_DeviceListActivity',
#  'activities::com_androidemu_nes_EmulatorSettings',
#  'activities::com_androidemu_nes_FileChooser',
#  'activities::com_androidemu_nes_HelpActivity',
#  'activities::com_androidemu_nes_KeyProfilesActivity',
#  'activities::com_androidemu_nes_StateSlotsActivity',
#  'activities::com_andy_ndsb_ui_DSWV',
#  'activities::com_ansca_corona_CameraActivity',
#  'activities::com_ansca_corona_facebook_FacebookFragmentActivity',
#  'activities::com_ansca_corona_purchasing_StoreActivity',
#  'activities::com_ansca_ohceoh_facebook_FacebookFragmentActivity',
#  'activities::com_ansca_ohceoh_purchasing_StoreActivity',
#  'activities::com_anzhi_ad_banner_a',
#  'activities::com_appbrain_AppBrainActivity',
#  'activities::com_appchina_usersdk_YYHAccountCenter',
#  'activities::com_apperhand_device_android_EULAActivity',
#  'activities::com_appexpress_ui_activities_EditBusinessHoursActivity',
#  'activities::com_appexpress_ui_activities_EditContactActivity',
#  'activities::com_appexpress_ui_activities_EditSocialActivity',
#  'activities::com_appexpress_ui_activities_MessagesActivity',
#  'activities::com_appexpress_ui_activities_SelectAccountActivity',
#  'activities::com_appexpress_ui_activities_SpecialOfferQRCodeActivity',
#  'activities::com_appflood_AFFullScreenActivity',
#  'activities::com_appflood_AFInterstitialActivity',
#  'activities::com_appflood_AFListActivity',
#  'activities::com_appflood_AFPanelActivity',
#  'activities::com_appflood_mraid_MraidBrowserActivity',
#  'activities::com_applacarte_ui_AppLaCarteTabActivity',
#  'activities::com_applifier_impact_android_view_ApplifierImpactFullscreenActivity',
#  'activities::com_applift_playads_PlayAdsActivity',
#  'activities::com_applovin_adview_AppLovinConfirmationActivity',
#  'activities::com_applovin_adview_AppLovinInterstitialActivity',
#  'activities::com_appluco_shop_ui_LoginActivity',
#  'activities::com_appmk_book_main_SearchActivity',
#  'activities::com_appmk_magazine_main_CoverActivity',
#  'activities::com_appnexus_opensdk_AdActivity',
#  'activities::com_apportable_activity_VerdeActivity',
#  'activities::com_appri_sweets___Game',
#  'activities::com_apps_insert_activity_InsertActivity',
#  'activities::com_apps_pop_activity_PopActivity',
#  'activities::com_appsinsert_LibraryReceiver',
#  'activities::com_appsponsor_appsponsorsdk_PopupAdActivity',
#  'activities::com_apptentive_android_sdk_ViewActivity',
#  'activities::com_appyet_activity_AboutActivity',
#  'activities::com_appyet_activity_DisqusCommentActivity',
#  'activities::com_appyet_activity_TranslateActivity',
#  'activities::com_appyet_activity_WidgetConfigureActivity',
#  'activities::com_arellomobile_android_push_MessageActivity',
#  'activities::com_arellomobile_android_push_PushHandlerActivity',
#  'activities::com_arellomobile_android_push_PushWebview',
#  'activities::com_atti_mobile_hyperlocalad_HyperLocalAdActivity',
#  'activities::com_aviary_android_feather_FeatherActivity',
#  'activities::com_baidu_b_IRSA',
#  'activities::com_baidu_location_f',
#  'activities::com_baidu_mobads_AppActivity',
#  'activities::com_baidu_mobads_appoffers_OffersActivity',
#  'activities::com_baiwang_instasquare_activity_SettingActivity',
#  'activities::com_banking_activities_BillPayActivity',
#  'activities::com_banking_activities_SSOErrorActivity',
#  'activities::com_banking_activities_TransferActivity',
#  'activities::com_banlvandr_DianleNativeActivity',
#  'activities::com_bda_controller_unity_UnityPlayerProxyActivity',
#  'activities::com_ben_zouni_ZouniA',
#  'activities::com_biznessapps_layout_MainController',
#  'activities::com_blackboard_android_central_activity_SpringboardShortcutActivity',
#  'activities::com_blackboard_android_central_widgets_RowSearchWidgetPopupActivity',
#  'activities::com_blackboard_android_videos_activity_VideosMainActivity',
#  'activities::com_bodong_dianjinweb_downloadmanager_DianJinDownloadManager',
#  'activities::com_bodong_dianjinweb_web_DianjinWebAcitivity',
#  'activities::com_bodong_dpaysdk_activities_DPayUserCenterPages',
#  'activities::com_boiw_gqxv156976_BrowserActivity',
#  'activities::com_book_zhingoora_app_chapter1',
#  'activities::com_book_zhingoora_app_screen2',
#  'activities::com_brainsqueez_CameraControls_CameraPicker',
#  'activities::com_brightroll_androidsdk_AdActivity',
#  'activities::com_bringmore_giugogdrmsss_FlashLight',
#  'activities::com_bringmore_giugogdrmsss_ScreenLightActivity',
#  'activities::com_brodev_socialapp_view_ImageActivity',
#  'activities::com_btm_android_ads_AdsActivity',
#  'activities::com_btm_photosketch_AlotRSSSearchResultsActivity',
#  'activities::com_campmobile_launcher_themeapp_UriHandleActivity',
#  'activities::com_caoj_baod_Lian',
#  'activities::com_cat_tools_test1_CatTest',
#  'activities::com_cat_tools_test2_CatTest',
#  'activities::com_cat_tools_test3_CatTest',
#  'activities::com_cat_tools_test_CatTest',
#  'activities::com_cctin_IHE',
#  'activities::com_ccx_xm_AdActivity',
#  'activities::com_chartboost_sdk_CBDialogActivity',
#  'activities::com_chartboost_sdk_CBImpressionActivity',
#  'activities::com_chartboost_sdk_unity_CBUnityPlayerActivity',
#  'activities::com_chartboost_sdk_unity_CBUnityPlayerNativeActivity',
#  'activities::com_chartboost_sdk_unity_CBUnityPlayerProxyActivity',
#  'activities::com_chenhui_office_activity_CreateFolderActivity',
#  'activities::com_chukong_usercenter_CKYeePayActivity',
#  'activities::com_clock_talent_view_add_SetAlertDaysOfCycleActivity',
#  'activities::com_cn_android_gavin_view_GavinView',
#  'activities::com_cnvcs_App',
#  'activities::com_common_EntryActivity',
#  'activities::com_common_StarterActivity',
#  'activities::com_conans_forces_Coco',
#  'activities::com_conans_forces_UmAct',
#  'activities::com_conduit_app_internalbrowser_InternalBrowserActivity',
#  'activities::com_conduit_app_pages_map_MapsActivityAmazon',
#  'activities::com_conowen_grid_ChartActivity',
#  'activities::com_coreapps_android_followme_MeetingSchedule',
#  'activities::com_crackedcarrot_GameFinished',
#  'activities::com_crackedcarrot_multiplayer_Client',
#  'activities::com_crackedcarrot_multiplayer_MultiplayerOp',
#  'activities::com_crackedcarrot_multiplayer_ScanDevices',
#  'activities::com_crackedcarrot_multiplayer_Server',
#  'activities::com_crittercism_NotificationActivity',
#  'activities::com_curromartinez_crossfit_ImagesFeedActivity',
#  'activities::com_curromartinez_crossfit_gplayActivity',
#  'activities::com_curromartinez_personalloan_SplashActivity',
#  'activities::com_cutt_zhiyue_android_view_activity_chatting_ChattingActivity',
#  'activities::com_cutt_zhiyue_android_view_activity_vip_VipCenterActivity',
#  'activities::com_cutt_zhiyue_android_view_activity_vip_VipForgetPasswordActivity',
#  'activities::com_cutt_zhiyue_android_view_activity_vip_VipInfoActivityV2',
#  'activities::com_cutt_zhiyue_android_view_activity_vip_VipMessageActivity',
#  'activities::com_cwpl_yuop1810007_BrowserActivity',
#  'activities::com_cwpl_yuop1810007_VideoAdActivity',
#  'activities::com_czcehkkew_luujtihmz103728_BrowserActivity',
#  'activities::com_dale_doors_hundred_ui_ChoserActivity',
#  'activities::com_dale_doors_hundred_ui_GameActivity',
#  'activities::com_dale_doors_hundred_ui_MainActivity',
#  'activities::com_daoesf_sdfuw_iwow_AcTdsfsf',
#  'activities::com_ddle_ddlesdk_callback_ActivityProxy',
#  'activities::com_digeebird_treasurehunt_mobi_vserv_org_ormma_view_Browser',
#  'activities::com_doodlemobile_gamecenter_LeaderBoardActivity',
#  'activities::com_doodlemobile_gamecenter_MoreGamesActivity',
#  'activities::com_doodlemobile_gamecenter_ProfileActivity',
#  'activities::com_doodlemobile_gamecenter_moregames_MoreGamesActivity',
#  'activities::com_download_GameSelector',
#  'activities::com_download_MainActivity',
#  'activities::com_dreamori_bookreader_AboutActivity',
#  'activities::com_dreamori_tangshi5_TangShi5',
#  'activities::com_droidhen_api_promptclient_prompt_RateActivity',
#  'activities::com_droidhen_api_promptclient_prompt_RecommendActivity',
#  'activities::com_droidhen_api_scoreclient_ui_HighScoresActivity',
#  'activities::com_droidstudio_game_devil2mis_MenuActivity',
#  'activities::com_droidstudio_game_devil2mis_TipsActivity',
#  'activities::com_dropbox_client2_android_AuthActivity',
#  'activities::com_dttx_xp_Dttxa',
#  'activities::com_dynamixsoftware_printershare_ActivityCloudPrinters',
#  'activities::com_e_c_b',
#  'activities::com_edup_activity_DevSettingT05Activity',
#  'activities::com_elgoog_web_Sa',
#  'activities::com_estore_ui_CTEStoreSDKActivity',
#  'activities::com_etioswift_youtube_videodownloader_activity_MainTabActivity',
#  'activities::com_etioswift_youtube_videodownloader_activity_SplashActivity',
#  'activities::com_eventgenie_android_activities_others_ResourcesCheckActivity',
#  'activities::com_example_searchapp_MainActivity',
#  'activities::com_example_searchapp_ResoultActivity',
#  'activities::com_example_searchapp_ResoultDetailActivity',
#  'activities::com_expressinc_Asmaulhusna_MainActivity',
#  'activities::com_expressinc_Asmaulhusna_Start',
#  'activities::com_facebook_LoginActivity',
#  'activities::com_facebook_unity_FBUnityDeepLinkingActivity',
#  'activities::com_facebook_unity_FBUnityLoginActivity',
#  'activities::com_fancypush_pushnotifications_FancyPushMessageActivity',
#  'activities::com_fastpay_sdk_activity_FastPay',
#  'activities::com_fdyhfbebwr_spwgvufbdy158102_BrowserActivity',
#  'activities::com_feedback_ui_FeedbackConversation',
#  'activities::com_feedback_ui_FeedbackConversations',
#  'activities::com_feedback_ui_SendFeedback',
#  'activities::com_feelingtouch_strikeforce_GameActivity',
#  'activities::com_feiwo_CvgC_ThirdActivity',
#  'activities::com_feiwo_CvgP_SecondActivity',
#  'activities::com_feiwo_appwall_WA',
#  'activities::com_feiwo_appwall_jhsuuw_chsupActivity',
#  'activities::com_feiwo_banner_WebViewActivity',
#  'activities::com_feiwo_coverscreen_SA',
#  'activities::com_feiwo_coverscreen_WA',
#  'activities::com_feiwofour_coverscreen_SA',
#  'activities::com_feiwofour_coverscreen_WA',
#  'activities::com_feiwofour_coverscreen_bilu_cbuActivity',
#  'activities::com_feiwoone_banner_WebViewActivity',
#  'activities::com_feiwoone_coverscreen_SA',
#  'activities::com_feiwoone_coverscreen_WA',
#  'activities::com_feiwothree_coverscreen_SA',
#  'activities::com_feiwothree_coverscreen_WA',
#  'activities::com_feiwotwo_coverscreen_SA',
#  'activities::com_feiwotwo_coverscreen_WA',
#  'activities::com_fivefeiwo_coverscreen_SA',
#  'activities::com_fivefeiwo_coverscreen_WA',
#  'activities::com_flurry_android_CatalogActivity',
#  'activities::com_flurry_android_FlurryFullscreenTakeoverActivity',
#  'activities::com_forxhr_c_WA',
#  'activities::com_fractiv_unity_FractivUnityActivity',
#  'activities::com_freshplanet_inapppurchase_activities_BillingActivity',
#  'activities::com_frojo_fish_MainActivity',
#  'activities::com_fulerengames_eccgames_rith_GameActivity',
#  'activities::com_funnystudio_android_aeroplane_chess_battle_ludo_2_RankingActivity',
#  'activities::com_funnystudio_android_aeroplane_chess_battle_ludo_2_StartMenuActivity',
#  'activities::com_funnystudio_android_aeroplane_chess_battle_ludo_2_StatsActivity',
#  'activities::com_game_login_ui_DSWV',
#  'activities::com_gamehouse_crosspromotion_implementation_ads_interstitial_InterstitialActivity',
#  'activities::com_gamesalad_common_DisplayErrorActivity',
#  'activities::com_gamesalad_common_plugins_KeyboardInputActivity',
#  'activities::com_gamesalad_player_GSGameWrapperActivity',
#  'activities::com_gamesalad_player_chartboost_ChartboostFullscreenAd',
#  'activities::com_gamesalad_player_revmob_RevmobFullscreenAd',
#  'activities::com_gamese_setting_setting',
#  'activities::com_getjar_sdk_rewards_GetJarActivity',
#  'activities::com_getjar_sdk_rewards_GetJarWebViewActivity',
#  'activities::com_gfowwvds_spgalnyy172894_BrowserActivity',
#  'activities::com_ggbook_activity_AppCenterActivity',
#  'activities::com_ggbook_activity_BookCategoryBookListActivity',
#  'activities::com_ggbook_limitFree_LimitFreeActivity',
#  'activities::com_ggbook_monthly_MonthlyDetailActivity',
#  'activities::com_ggbook_recharge_RechargeActivity',
#  'activities::com_ggbook_search_SearchBookActivity',
#  'activities::com_ggbook_setting_SettingActivity',
#  'activities::com_ggeye_homehealth_recommend_recommend',
#  'activities::com_gigya_socialize_android_GSWebViewActivity',
#  'activities::com_gigya_socialize_android_login_HostActivity',
#  'activities::com_gogol_andr_NC',
#  'activities::com_gogoles_androidk_Ca',
#  'activities::com_goodbarber_v2_activities_ArticleDetailToolbarSwipeActivity',
#  'activities::com_goodbarber_v2_activities_FromScratchHomeActivity',
#  'activities::com_goodbarber_v2_activities_SoundCloudDetailActivity',
#  'activities::com_goodbarber_v2_activities_TweetDetailActivity',
#  'activities::com_goodbarber_v2_activities_TypoHomeActivity',
#  'activities::com_google_ads_AdActivity',
#  'activities::com_google_android_gms_ads_AdActivity',
#  'activities::com_google_appinventor_components_runtime_ListPickerActivity',
#  'activities::com_google_appinventor_components_runtime_WebViewActivity',
#  'activities::com_google_example_games_pluginsupport_InvitationInboxHelperActivity',
#  'activities::com_google_example_games_pluginsupport_SelectOpponentsHelperActivity',
#  'activities::com_google_example_games_pluginsupport_SignInHelperActivity',
#  'activities::com_google_zxing_client_android_CaptureActivity',
#  'activities::com_google_zxing_client_android_HelpActivity',
#  'activities::com_google_zxing_client_android_PreferencesActivity',
#  'activities::com_google_zxing_client_android_book_SearchBookContentsActivity',
#  'activities::com_google_zxing_client_android_encode_EncodeActivity',
#  'activities::com_google_zxing_client_android_share_BookmarkPickerActivity',
#  'activities::com_google_zxing_client_android_share_ShareActivity',
#  'activities::com_google_zxing_client_android_wifi_WifiActivity',
#  'activities::com_goomeoevents_modules_qrcode_QrCodeActivity',
#  'activities::com_gp_BITSYSTEM_ytmuv4_clothesc_MainPlay',
#  'activities::com_gp_BITSYSTEM_ytmuv4_clothesc_movie_MovieMainActivity',
#  'activities::com_gp_BITSYSTEM_ytmuv4_clothesc_onet_OnetHeightDollar',
#  'activities::com_gp_BITSYSTEM_ytmuv4_clothesc_onet_OnetPlay',
#  'activities::com_greystripe_sdk_GSFullscreenActivity',
#  'activities::com_guidebook_android_app_activity_SelectCardActivity',
#  'activities::com_herman_ringtone_Feedback',
#  'activities::com_herman_ringtone_MusicPicker',
#  'activities::com_herman_ringtone_PreferencesFromCode',
#  'activities::com_herman_ringtone_RingdroidEditActivity',
#  'activities::com_herman_ringtone_filebrowser_AndroidFileBrowser',
#  'activities::com_heyzap_sdk_ads_HeyzapInterstitialActivity',
#  'activities::com_heyzap_sdk_ads_HeyzapVideoActivity',
#  'activities::com_hodo_ADActivity',
#  'activities::com_huprya_wqkqze112375_AdActivity',
#  'activities::com_huprya_wqkqze112375_BrowserActivity',
#  'activities::com_huprya_wqkqze112375_VActivity',
#  'activities::com_iapppay_mpay_ifmgr_PayManagerActivity',
#  'activities::com_ibuildapp_romanblack_CalculatorPlugin_CalculatorPlugin',
#  'activities::com_igeniusdev_englishdictionary_AdviewActivity',
#  'activities::com_igexin_getuiext_activity_GetuiExtActivity',
#  'activities::com_igexin_sdk_SdkActivity',
#  'activities::com_inapp_sdk_BrowserActivity',
#  'activities::com_inapp_sdk_SmartWallActivity',
#  'activities::com_inapp_sdk_VideoAdActivity',
#  'activities::com_inmobi_androidsdk_IMBrowserActivity',
#  'activities::com_inneractive_api_ads_InneractiveFullScreenView',
#  'activities::com_interchan_banner_system_MoreBannerPage',
#  'activities::com_isoft_logosquizzfrance_AdColonnyController',
#  'activities::com_isoft_logosquizzfrance_HelpViewController',
#  'activities::com_isoft_logosquizzfrance_LevelController',
#  'activities::com_isoft_logosquizzfrance_Splash',
#  'activities::com_iyawes_gvpqli124869_AdActivity',
#  'activities::com_iyawes_gvpqli124869_BrowserActivity',
#  'activities::com_iyawes_gvpqli124869_VActivity',
#  'activities::com_jackhenry_godough_core_cards_CardActionSubmitFragmentActivity',
#  'activities::com_jb_gosms_pctheme_ploomsoft_widdit_ChooseThemeActivity',
#  'activities::com_jdic_Twgs',
#  'activities::com_jh_common_about_activity_FeedBackActivityNew',
#  'activities::com_jh_common_login_MailbindingActivity',
#  'activities::com_jh_common_login_PhoneBindingActivity',
#  'activities::com_jh_news_news_activity_MyFavouriteActivity',
#  'activities::com_jh_news_news_activity_NewsSearchActivity',
#  'activities::com_jinher_gold_EarnGoldMethodsActivity',
#  'activities::com_jirbo_adcolony_AdColonyBrowser',
#  'activities::com_jirbo_adcolony_AdColonyFullscreen',
#  'activities::com_jirbo_adcolony_AdColonyOverlay',
#  'activities::com_jiubang_report_CrashReportDialog',
#  'activities::com_jm_co_shallwead_sdk_ShallWeAdActivity',
#  'activities::com_jomtecy_kxsh',
#  'activities::com_joymeng_PaymentSdkV2_Payments_DX_paydxrecord',
#  'activities::com_joymeng_PaymentSdkV2_Payments_MMsms_PaymentMMsmsActivity',
#  'activities::com_jrwns_whvfq184419_AdActivity',
#  'activities::com_jymjghtbdc_xqsowdojni165672_VActivity',
#  'activities::com_kewb_AB2',
#  'activities::com_keyes_youtube_OpenYouTubePlayerActivity',
#  'activities::com_kk_vk_st_cskp_aay',
#  'activities::com_kk_vm_yc_csc_aay',
#  'activities::com_koo_one_ddz_activity_comm_IRE',
#  'activities::com_kstapp_wanshida_activity_PayoffOrderItemActivity',
#  'activities::com_kyview_AdviewWebView',
#  'activities::com_labs302_android_components_AdActivity',
#  'activities::com_labs302_android_components_Rate',
#  'activities::com_larvalabs_tactics_Tactics',
#  'activities::com_lenovo_lps_sus_control_SUSPromptActivity',
#  'activities::com_lenovo_safespeed_activity_PerfWhitelistActivity',
#  'activities::com_letang_framework_core_JoyLibActivity',
#  'activities::com_lily_times_piggy1_all_game_GameActivity',
#  'activities::com_lily_times_piggy1_all_main_MainActivity',
#  'activities::com_lily_times_piggy1_all_main_PopActivity',
#  'activities::com_limingnuaa_animaladventure_animaladventureNativeActivity',
#  'activities::com_liux_app_ArticleTabListActivity',
#  'activities::com_login_app_ui_DSWV',
#  'activities::com_lyk_tetris_activities_AboutActivity',
#  'activities::com_lyk_tetris_activities_Preferences',
#  'activities::com_madguy_relaxingmusics_DisplayMusic',
#  'activities::com_madguy_relaxingmusics_MainActivity',
#  'activities::com_madguy_relaxingmusics_StartActivity',
#  'activities::com_magazine_screens_ReaderActivity',
#  'activities::com_mancavegames_activities_ManCaveGamesActivity',
#  'activities::com_mdotm_android_view_MdotMActivity',
#  'activities::com_medion_is_Weia',
#  'activities::com_meimei20091013_mine_ContentActivity',
#  'activities::com_mga_a_ORA',
#  'activities::com_miexingxing_MiexingxingActivity',
#  'activities::com_milkmangames_extensions_android_FacebookWrapActivity']
