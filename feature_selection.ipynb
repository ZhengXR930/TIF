# %%
import os
import pandas as pd
import numpy as np
import pickle
import joblib

dataset_folder = "/scratch_NOT_BACKED_UP/NOT_BACKED_UP/xinran/dataset/drebin"
years = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']


dfs_train = []
dfs_test = []
dfs_test_year = []
for month in months:
    file_path = os.path.join(dataset_folder, f'2014-{month}', 'features.pkl')
    if os.path.exists(file_path):
        data = joblib.load(file_path)
        dfs_train.append(data)

df_train = pd.concat(dfs_train, ignore_index=True)
print(df_train.shape)
seen_families = set(df_train['family'])
seen_families.remove('benign')
# if 'unknown' in seen_families:
#     seen_families.remove('unknown')
# if 'jiagu' in seen_families:
#     seen_families.remove('jiagu')
seen_family_num = df_train[df_train['family'].isin(seen_families)].shape[0]
unknown_family_num = df_train[df_train['family'] == 'unknown'].shape[0]
benign_family_num = df_train[df_train['family'] == 'benign'].shape[0]
jiagu_family_num = df_train[df_train['family'] == 'jiagu'].shape[0]
print(f"number of seen family: {seen_family_num}, number of unknown family: {unknown_family_num}, number of benign family: {benign_family_num}, number of jiagu family: {jiagu_family_num}")

for year in years:
    for month in months:
        if year == '2025' and month > '09':
            break
        file_path = os.path.join(dataset_folder, f'{year}-{month}', 'features.pkl')
        if os.path.exists(file_path):
            data = joblib.load(file_path)
            dfs_test.append(data)
            dfs_test_year.append(data)
    if dfs_test_year:
        df_test_year = pd.concat(dfs_test_year, ignore_index=True)
    dfs_test_year = []
    year_family_test = set(df_test_year['family'])
    seen_family_test = seen_families & year_family_test
    unseen_family_test = year_family_test - seen_families
    if 'unknown' in seen_family_test:
        seen_family_test.remove('unknown')
    # if 'unknown' in unseen_family_test:
    #     unseen_family_test.remove('unknown')
    if 'benign' in unseen_family_test:
        unseen_family_test.remove('benign')
    if 'benign' in seen_family_test:
        seen_family_test.remove('benign')
    jiagu_family_num = df_test_year[df_test_year['family'] == 'jiagu'].shape[0]
    seen_family_num = df_test_year[df_test_year['family'].isin(seen_family_test)].shape[0]
    unseen_family_num = df_test_year[df_test_year['family'].isin(unseen_family_test)].shape[0]
    unknown_family_num = df_test_year[df_test_year['family'] == 'unknown'].shape[0]
    benign_family_num = df_test_year[df_test_year['family'] == 'benign'].shape[0]
    print(f"year: {year}, shape: {df_test_year.shape}, number of seen family: {seen_family_num}, number of unseen family: {unseen_family_num}, number of unknown family: {unknown_family_num}, number of benign family: {benign_family_num}, number of jiagu family: {jiagu_family_num}")



# df_test = pd.concat(dfs_test)
# print(df_test.shape)

# print(df_train.columns)
# print(df_test.columns)
        



# allocate type to each row
# Out:
# (51953, 7)
# number of seen family: 5417, number of unknown family: 263, number of benign family: 46536, number of jiagu family: 10
# year: 2014, shape: (51953, 7), number of seen family: 5154, number of unseen family: 0, number of unknown family: 263, number of benign family: 46536, number of jiagu family: 10
# year: 2015, shape: (35768, 7), number of seen family: 7369, number of unseen family: 2761, number of unknown family: 391, number of benign family: 25247, number of jiagu family: 92
# year: 2016, shape: (38612, 7), number of seen family: 3304, number of unseen family: 887, number of unknown family: 690, number of benign family: 33731, number of jiagu family: 758
# year: 2017, shape: (63525, 7), number of seen family: 2829, number of unseen family: 490, number of unknown family: 4273, number of benign family: 55933, number of jiagu family: 984
# ...

# %%
import os
import pandas as pd
import numpy as np
import pickle
from collections import Counter

with open("/scratch_NOT_BACKED_UP/NOT_BACKED_UP/xinran/dataset/processed_features/train_data.pkl", 'rb') as f:
        data = pickle.load(f)
print(f"keys: {data.keys()}")
x_data = data['X']
y_data = data['y']
env_data = data['env']
y_family = data['y_family']

print(f"X shape: {x_data.shape}, y shape: {y_data.shape}, y distribution: {Counter(y_data)}, env shape: {env_data.shape}")
print(Counter(data['y_family']))
print(Counter(y_family[y_family == 5]))
# Out:
# keys: dict_keys(['X', 'y', 't', 'env', 'y_family'])
# X shape: (41562, 5814), y shape: (41562,), y distribution: Counter({0.0: 37228, 1.0: 4334}), env shape: (41562,)
# Counter({37: 37228, 2: 1659, 4: 789, 5: 389, 0: 210, 7: 209, 1: 170, 11: 169, 3: 97, 42: 71, 14: 59, 24: 41, 17: 37, 6: 34, 18: 28, 19: 24, 39: 20, 63: 20, 27: 20, 13: 19, 25: 19, 35: 17, 23: 17, 31: 15, 22: 15, 20: 14, 15: 11, 21: 11, 8: 11, 12: 10, 70: 9, 32: 7, 29: 7, 48: 7, 74: 6, 79: 6, 36: 5, 26: 5, 69: 5, 45: 5, 40: 5, 50: 5, 47: 4, 30: 4, 71: 3, 65: 3, 61: 3, 33: 3, 76: 3, 68: 2, 60: 2, 10: 2, 55: 2, 62: 2, 46: 2, 54: 1, 38: 1, 44: 1, 53: 1, 77: 1, 72: 1, 78: 1, 9: 1, 41: 1, 34: 1, 59: 1, 52: 1, 57: 1, 16: 1, 64: 1, 51: 1, 56: 1, 28: 1, 49: 1, 66: 1, 58: 1, 73: 1})
# Counter({5: 389})
